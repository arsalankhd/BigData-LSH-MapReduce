# %% [markdown]
# # Big Data LSH & MapReduce

# %% [markdown]
# ## Improrting Libraries

# %%
import pandas as pd 
import random
import hashlib
from collections import defaultdict
from itertools import combinations
import csv

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## LSH

# %% [markdown]
# **Load Data**

# %%
train_df = pd.read_csv("Data\yelp_train.csv")
val_df = pd.read_csv('Data\yelp_val.csv')
test_df = pd.read_csv('Data\yelp_test.csv')
df = pd.concat([train_df, val_df, test_df], ignore_index=True)
df.columns = df.columns.str.strip()

# %% [markdown]
# **Preprocessing**

# %%
user_business_map = defaultdict(set)
business_users_map = defaultdict(set)

# %%
for _, row in df.iterrows():
    user = row['user_id'].strip()
    business = row['business_id'].strip()
    user_business_map[user].add(business)
    business_users_map[business].add(user)

# %%
user_id_index = {user_id: idx for idx, user_id in enumerate(user_business_map)}

# %%
user_id_index
# Out:
# {'vxR_YV0atFxIxfOnF9uHjQ': 0,
#  'o0p-iTC5yTBV5Yab_7es4g': 1,
#  '-qj9ouN0bzMXz1vfEslG-A': 2,
#  'E43QxgV87Ij6KxMCHcijKw': 3,
#  'T13IBpJITI32a1k41rc-tg': 4,
#  'Q1IENmNc6bdDruACmhy4mg': 5,
#  '4bQqil4770ey8GfhBgEGuw': 6,
#  '0BBUmH7Krcax1RZgbH4fSA': 7,
#  'QZ_Arlwoj0ghfBvg69rjOw': 8,
#  'lEw2VL9JCDFk3R5NzahqnA': 9,
#  'zsZBYWYEmLLs81_f-HHM8w': 10,
#  'uNxXIIFzjHm5r62UTyVjrQ': 11,
#  'TGrZk61ja7X1ijAGW5lNmg': 12,
#  'Fv0e9RIV9jw5TX3ctA1WbA': 13,
#  'z4RytucxI_XfcMFaEI2DRg': 14,
#  'y0ZU1w6YY4W-KtMeRXSYLg': 15,
#  'BeoFmNoFuz-h8uso-J2_lg': 16,
#  'pMefTWo6gMdx8WhYSA2u3w': 17,
#  'tYk7mMGGFl3gLfmhST5L-A': 18,
#  'Ez8ifxrtOUT5TM4817scOQ': 19,
#  'KhpA23RweKsO9TDaGpE2xg': 20,
#  'Bj_MarPEKBe2xN12YimekQ': 21,
#  'mrru6hbeQLvagU4vkfuqmw': 22,
#  'UYcmGbelzRa0Q6JqzLoguw': 23,
#  '0KeT9NKimYkHN0wlrij-dg': 24,
#  '0nqshyLgABOSyTfJUTthjQ': 25,
#  '3CMiTAhq_o_GP1tLs-ihbg': 26,
#  'vSzquh2Ym99tpksfpWH2kg': 27,
#  'PKEzKWv_FktMm2mGPjwd0Q': 28,
#  'sMm9HOXmBgsBmCKnOmLwyA': 29,
#  'E0v3KkPKsizW_RW3CKQj-A': 30,
#  'en3OMUKWjeON-1-6wo8VrQ': 31,
#  '8AwcaBJjiMpQ__FPxktwwQ': 32,
#  'ehAvwDt4Fpsz9KPordu5lA': 33,
#  'O5VAQ-dbR2Bk0OZLL1L0Ig': 34,
#  'HVJgTH5qu0goywOHNpOjPA': 35,
#  'WJhQpdUHoFCtpU6gHFjVlQ': 36,
#  'lCYaXiAQVY6vq2awuO2Siw': 396,
#  '9bZRfbCsuqatVXJzbYSrzQ': 397,
#  '3XSBHH432euFfSq9TBXXXg': 398,
#  'lFFIpfkox55FQ-wZD6BBVw': 399,
#  'ESCcbvs_p55nukBzCSCFaQ': 400,
#  'SRSmzTPA2dX2Zpfa2uE4sA': 401,
#  'yzwOcVyWuXQpmDlPXWw0Mw': 402,
#  'Gj5Dzcp-r794xHGRmoRKfQ': 403,
#  'Jt1zgNmwz_jheOSmEsljPQ': 404,
#  '-gQm-IoK2_BMEMx9OgtQnw': 405,
#  'TaVGX_tjR7_KTy3kbN7fnQ': 406,
#  'dmXpg_unok3cL3eW3RI0fA': 407,
#  'at0QjRaQpVlhXT8SbjGE1w': 408,
#  'lBYr_iY0idEpsVEQkaEBmg': 409,
#  '09QcQYf_t1NEq_AkjJuABA': 410,
#  'NTtgQrb8VGr_xKePhppqjA': 411,
#  'kbJeRTki8F984KdOlibxzA': 412,
#  'WvntDWMQnaEV8agu3gcTug': 413,
#  'PVyZXgOkVtnU6966FDFhuw': 414,
#  '_O5ajREINPG9zeyhW5Dmqg': 415,
#  'krJw8HFQMl2lP8fbHvEGuw': 416,
#  '3w6Gaq-SiVJwr7BOSRcu9A': 417,
#  'uz1_cds7yyehTPYnrArdYA': 418,
#  'N_LyFYrey_LuxJFkdFwRkw': 419,
#  'nFgdvXE0NfqQodRq1xICaw': 420,
#  'UmTMCfPlhA6kJLAsLycSfg': 421,
#  '48Jn_3tJ8iGI-FotO7pWVw': 422,
#  'LgFDWZTLi1w9OGi5BtKORg': 423,
#  'XTBfnHWtAgq2YauG06HIig': 424,
#  'xhhE0txKwQtRzgQVVdKkvg': 425,
#  '4WoAauE_v-vwMuQ665rMyA': 426,
#  '-ILapEusonY1QHyJPvUk2A': 427,
#  'uf1UdKswKWOqFLUvRvvbzA': 428,
#  'a2SODwNOs5INpZu4Z0E05A': 429,
#  'mLJ3zQwiEzAIBaXb-7iXBw': 430,
#  'LTxiFtf3WFiAiWMJgZpIXg': 431,
#  'kmE8w5Y785eZmodsx0V6Ag': 432,
#  'mu0HokS1Ly9_QZDRHEPQ8A': 433,
#  'cK-tsr9qzvDzq0UjmvDsuA': 434,
#  '4N-HU_T32hLENLntsNKNBg': 435,
#  'x9gFy2s_-9R9UBdwvY359w': 436,
#  'Ec7k5Nxp1rohv1f1nMU_ig': 437,
#  'F8I0FAZxzWJjcLoajsYK3Q': 438,
#  'qZa2urX00YWHs-jRcWgUqw': 439,
#  'pcv-MEpcI6t4_ytr49LFpw': 440,
#  'renPzRDqMZpMaHiCD_e1_A': 441,
#  'xnLliq9Majlk9i0Orf7Iig': 442,
#  'rGd8YUtvhSdMm8-9cMdQ4Q': 443,
#  'r0GLQAawvHXUd-xZow-fWQ': 444,
#  'yuhu7mu_VZeCOvKLRT-G0g': 445,
#  '0o8HUzggoNKay9-ZMj3HqQ': 446,
#  'x_kJi2ozLPgXhckevtjStA': 447,
#  '7UZ5w4eoo3dJOWRbHEaYwg': 601,
#  'WIu4IqktLQ6Qm46L5r5Baw': 602,
#  'E8w6O_CXuluNeo4K1JMIbQ': 603,
#  'gtEjMgcW74ZcG0zzMctmKg': 604,
#  'CNaaizAUc2c4WIb1M3BBPw': 605,
#  'S10Q9h_W-MKyog8IdcCNCQ': 606,
#  'KxrTQnzr83z0HZnrAkkeGQ': 607,
#  'M4yYtAXehUzaHB1ghl6EXg': 608,
#  'HK-TlD0yVA_tpTXZxfzu2w': 609,
#  '8Ae52apMLbD3jhHcaQ_Zzw': 610,
#  '2v48a6qYAdZdynQeB-qAMA': 611,
#  'zwo4S612wfakZodLQ8aMIQ': 612,
#  'uZXbI_tBHtEt0Y0UEAYz3g': 613,
#  'wxQCLMnuVYbdtmQCc2ryZg': 614,
#  'fVILhIglx6RNOXQba5t4kQ': 615,
#  'uTu74kG-S_54TpMNtBC04w': 616,
#  '5wRCMyU9dEdkja_mO0qfeQ': 617,
#  '0DGh3LaLFDDES3OtOqGq1w': 618,
#  'zWWcik1fRPZviBCQLC26FQ': 619,
#  'cH87FZ31P6kf9oU5JgUTkQ': 620,
#  'sAEUJb9C6_ekgc8BIScZ5w': 621,
#  'c2MQ_LPuvtiiKFR_-OY9pg': 622,
#  '_d74r_wGLwE4E8MxRKk-FQ': 623,
#  'QYobbHEmhLGuS6QDqVRTLw': 624,
#  'xEbCNG-3GTw-OxFusnVP9g': 625,
#  'N1eblziJZ5N4OcO2HYWZFA': 626,
#  'Kj9cFO70zZOQorN0mgeLWA': 627,
#  'PSI7wvuqEhhV9Jh_fP2eZQ': 628,
#  '8VkGyOMqDRPuLFTbTpXLeg': 629,
#  'Slp2CsM93OBoTrbt6iPpvw': 630,
#  'KvNTqEG5tUDyrhX4o7NENQ': 631,
#  'hdCbb8fTbebPZl2TQC4HtA': 632,
#  'zzPvEodjvLPe-5NvV0U_cg': 633,
#  'YA-caxALI4C-eCiSM97new': 634,
#  'jwctwzboGhQmtC50Juxa9A': 635,
#  'TDASnrM4Siq3JIhGiG2Nbw': 636,
#  'Xwnf20FKuikiHcSpcEbpKQ': 637,
#  'woT2AcKuonN5L1N8h1HGMA': 638,
#  '-d2daWmftYumOaYpbD5D8Q': 639,
#  'le3Xn9Mheb1hNxWurF7RSw': 640,
#  'oWxy_YR6n2w8e9L00hxhPw': 641,
#  '_ReaelzjXLsmi1BTbvCINA': 642,
#  'KBHTIaz-OdXukREefkP4qg': 643,
#  'lf1m4CbheuUR7fFZoLGRvA': 644,
#  '--Qh8yKWAvIP4V4K8ZPfHA': 645,
#  'dnb5YD_qxGybsARPG3bQ0g': 646,
#  's2o_JsABvrZVm_T03qrBUw': 647,
#  'OVnfDg-KuGWyDocYdKkmPQ': 648,
#  '0hZfE2He1YssM_wEvKhfcA': 649,
#  'EiwxlbR8fb68lMgEXhcWKA': 650,
#  'QlRsVCCytArycuuKSyUBLg': 651,
#  'yy_KQA1FtwilaG-7LB4BgA': 652,
#  '_v0vHYNotjS0wo6dwCCpGA': 653,
#  'X-VOe5bzT9EJu_L_Bt0nLQ': 654,
#  '2MtL65B0hy5L41TFBRIdYg': 655,
#  'VLy6l8L72adD7iTBNqiPXw': 656,
#  'IEQjRwcXUJQ4J-x4H6Nfsg': 657,
#  'ltTLCzM4p-1cnC70SPNfSA': 658,
#  'NYxQwZ7ftzfBeE0HJolpEg': 659,
#  'eZeBuiVZWT7u3SktO7mv9w': 660,
#  'Bf-X9oxiiRvzgrwguUWoeg': 661,
#  'BkMqpJikNc3r5itc-ui6ww': 662,
#  'm7z-tX6XDZ27xGhGjnI21w': 663,
#  'CQ67NJigSe5-uBDX3b_CUw': 664,
#  'IrrulcUUCHg3deMsrdF_xg': 665,
#  '0EJNWlsatHyfSr2jJ3BJ6g': 666,
#  '4KbUaerUBoiUwZGMHKVFxQ': 667,
#  'Z88N6qly3Dp5C06XbZ9IMQ': 668,
#  't2O6rs4fZeY9o6ZY52RyJA': 669,
#  '9J7ifUhXuHiW4hsWiMt6zA': 670,
#  '2-01LlVLrCujcL1kT2Xchw': 671,
#  '0GTanD35lGadNgiDp_a8cQ': 672,
#  'LRv--ZITTTiKRXC171WHtg': 673,
#  '8l6mJUy1jMEjso7iMQHHgg': 674,
#  'Vqp0dpug9Db-kFHO3PkAaQ': 675,
#  'W1RXN13QRcnnMQImd2rhKw': 676,
#  'w2PyT_BYJSHOlCyxh8LzzQ': 677,
#  'yxtwZzmnCYiMatSeT65rAA': 678,
#  'dD5vTDPzv_79m8_zZhc9hA': 679,
#  'uPtcm-krVuWIyY4UIJqDFg': 680,
#  'loHq4MfAzNeWidlVBK3k9g': 681,
#  'zKCAyo1rdFKu8xQGivJeUw': 682,
#  '4qmjySJprpPSKDoxHLIuEQ': 683,
#  '3MwccEgTNoXgc-en9e7Qzw': 684,
#  'EiP1OFgs-XGcKZux0OKWIA': 685,
#  'HkgxlKEdsdEK-qsiBgrq6Q': 686,
#  'jjogE_kPPMjxKvDEFlct6w': 687,
#  'wi0dVER4HBLYEmYHoqu-Ew': 688,
#  'veLWPGA-1MMtcRNDYWm-BA': 689,
#  'MWuVbyBgP4vD24Rc7UH5xw': 690,
#  '1XrB44t6fDgSabcsWbI0Qw': 691,
#  'w5bwTIjGTebtlWEEAxfKhg': 692,
#  'L8cvMZLWmM4qWTl9SkxJ8g': 693,
#  '8YZoHo__JAcce_7nwuyAVw': 694,
#  'uaN7sGhKZ_N8PPxDFmLdlA': 695,
#  'eq8AqFaTMBL4GmAYf1vUeQ': 696,
#  '_N8YA_UiSwUIXoyHBx_qrw': 697,
#  'gMfkWTxRVZtJAMm_adQKsQ': 698,
#  'OLn8EvPsu4hNug8V5PF2jA': 699,
#  'ZTKSgba01lWMKT2RUbCGrg': 700,
#  'rypcWiSNGM0suWsiSLh9xA': 701,
#  '8k4hOmF4tJflaUGsUIdqMw': 702,
#  'ssgRnGGXxigWTEXM-n92lg': 703,
#  '7HFkF9A2xaHxLqwcFnJ0JQ': 704,
#  '9W73B44Iw8WslrTNB2CdCg': 705,
#  'N8bPJNrqCGuUAazxqO9vHA': 706,
#  'VvYC7DUlWds5H2fs8nyeUQ': 707,
#  'SxcN4e5SKNhZ4wfEUbAMRA': 708,
#  'y-OW396z2nqGyyklOLnVjw': 709,
#  'ImBb4MxG9wfTkZfOcfZhJQ': 710,
#  'n86B7IkbU20AkxlFX_5aew': 711,
#  '6cW8GuKZyFjpg29djEJoPg': 712,
#  'zsZVg16yjZu5NIiS0ayjrQ': 713,
#  'vy6bsyGB80NX24wddBb--g': 714,
#  '2oTG2GrBpikkonRxQywI7Q': 715,
#  '2VKVhy1SwaixHCeiWglLUQ': 716,
#  'W5GNz_rDc9r37Uav1mdocg': 717,
#  'kSOkDKEdCzDjOVFaqOcTKQ': 718,
#  'UVVzF9WtTkTODPBTetJUDw': 719,
#  'j97PtHlFcx7jhmV_1eQdtw': 720,
#  'hCy4Kkyo4N0fFLMDpKjYyw': 721,
#  'Pm1bHgmnkOJOFkHPAr7PjQ': 722,
#  'WnUDyIE3YWdHcON-i-1MKw': 723,
#  'Bwa7MWEM88FtiNLaXWCkww': 724,
#  '3yMtpQ_wV4ZGg6E69uE1PQ': 725,
#  'U_ocWuKYVev4OvcA7xIGwQ': 726,
#  'NcUPsHsnF7HBbVjjmoYElw': 727,
#  '75DUiVsWkGZRW--zySVORA': 728,
#  'hMY0wsj3VxOaBixV_6YnuA': 729,
#  'GtMg9Ooc2ykPD0OV5P3pzw': 730,
#  'mgBV3YmtaEqKmvrOHKQXfA': 731,
#  'HmN7p502YMJGkBNv5bzi1w': 732,
#  'JKzqdJ8Xe7uHHcQo5vthNA': 733,
#  'Mv55A30nEcAl3vk4qow5dA': 734,
#  'wXdrUQg4-VkSZH1FG4Byzw': 735,
#  'NGLufCod1pP760aBucp3tw': 736,
#  'qF1V8GyuLL5Fpv40Cyturw': 737,
#  'A0Z_UchZuzddAJjnay2f0g': 738,
#  'n5HCox_qsCR-DidvPzyctA': 739,
#  'X1Cy1xsDawDiH0o9dmDIXA': 740,
#  'bOHx6q63sD0jhtV3CLolhA': 741,
#  'JQlzHruOqwMuueStY_9_DA': 742,
#  'iJCtRAlSvxiUuKlVAnsq0A': 743,
#  'sOL82Hbfza89tKL6m_wBJA': 744,
#  's1hZZMkaWCql09X-cGUQEQ': 745,
#  'mFwRTTDW0Yr-rFkTF2cFsw': 746,
#  '-C-l8EHSLXtZZVfUAUhsPA': 747,
#  'yEmeRQb4WH6NN0IAaTX_lw': 748,
#  '4-ut9noMzEf0is9W-8CPnQ': 749,
#  'LoLmkPhGZr-2FlWSUCE-Kg': 750,
#  'tAFMvCqZel6t6Fp5QdxD7w': 751,
#  'ePWsbOWDTJcgIus-BFuKpg': 752,
#  'miClbIxZOkKbOhNmbCetSA': 753,
#  '750rhwO7D_Cul7_GtO9Jsg': 754,
#  'a_5PHpKHFQYtVgEr4QTUMA': 755,
#  '5CgjjDAic2-FAvCtiHpytA': 756,
#  'C0pdHsyteZwP-7R1yhJIeQ': 757,
#  '7V7hxX3R7889HvKWJqgGWQ': 758,
#  'p4WztGxrJBrVWmt-xmY5Fg': 759,
#  'BcWoqczYhcM8_qQZGc9zqQ': 760,
#  'peVsgFj0qa8SErmzIDM0lg': 761,
#  'dArzYnlZh0gBLjA6YkJeoQ': 762,
#  'MXE5dJEqzzfKDLEGkHbdVA': 763,
#  'Z0GA65zCMI4ska4iHRr8Bg': 764,
#  'e0AUdCu-jeOkLImiEzlTDg': 765,
#  'LGoYq9EufN34Es2r9i5mpg': 766,
#  'wFDewm6fvtVRZ0te5em63A': 767,
#  'vX72EYVC9tff84HgGWPv_Q': 768,
#  'R7G6h1iMjTfBlJ_7_5lTJw': 769,
#  'BO1A62kTQk4MfwZPOD9sKg': 770,
#  'Yl7OYdHuYmr7K-IW9_ayng': 771,
#  'YEZNR83u5qi3-boq-MkdaQ': 772,
#  'UJ4uCYEppIIo9IRGMx5E1A': 773,
#  'bXCOHfm2PK-L2c0mH8Iy1A': 774,
#  'iX1IIVWt5__u7ykkczLsRA': 775,
#  'j6Bdnlcu3mwrDmDIOPXbSg': 776,
#  'j9vih1KD2r-NLlaHfZPkRA': 777,
#  'i7QG1ixeuFwpemeLvmRKHA': 778,
#  'gwFDKT3MoW3mBm0n9P_ATQ': 779,
#  'P-3Q0haxyKO3JLHnQo83Bw': 780,
#  'QozLnf7sjzQ0IRzEAsepKQ': 781,
#  'uBHRgjD2xy77JCVm7CwmOA': 782,
#  'mLmgtTwuryDjJAQrSZ_w5w': 783,
#  'U1XB9-3lh8Z3Eki6qU-v2g': 784,
#  'jR00ESlM7Rmg9tFYwMbh4A': 785,
#  'CTaZ3ebFGQMHaLZhnO2EuA': 786,
#  'ZnIaEvJwrxlBUjimIpx2Qw': 787,
#  'sWKaLjpYG6VABf23CXDhyA': 788,
#  'dmRueUwj0JMTlNZfTj3ZWA': 789,
#  'X0ThBT2nXkeEFzd7RSuy6Q': 790,
#  'oigPots1DGB1tRxb8H-xaA': 791,
#  'Jbd1x8jj3EgOkQMZ3RImKw': 792,
#  '19uBC840gZ-BrIfI3Fae4w': 793,
#  'rt3PC7WCgCKsoufmQJELfw': 794,
#  '0lv7YK1Jmwp4iVWUIjHqcQ': 795,
#  'fcD5KiJ_ACTsU6zLJR6CuQ': 796,
#  's-QuErK1oRlAzT5qnO6FOQ': 797,
#  'hzKQOJI8-7TM-BstJpSVCA': 798,
#  'NS3B17yHv2lBJfGuwSmVNw': 799,
#  'Y1N7LPhi3xAq3UBLKWpWNQ': 800,
#  'QrtY7-PmgiBkBT8LPYSqwQ': 801,
#  'JgW2N6iok_iBytH2A3v5sw': 802,
#  'MjuZV5DMV87iDhkNrqQkPQ': 803,
#  'vwLV4TkRMoghs86tB1Ke8Q': 804,
#  'AhoxHm569hH_PRkoegDwcA': 805,
#  'JYcCYNWs8Ul6ewG5kCYW4Q': 806,
#  'ykBj3RG8-bSN5FOLAccGpw': 807,
#  'ZC0v-coaz3wUgXL6yjphjg': 808,
#  'hR8LdFd3hskR0eZbuMT31Q': 809,
#  'yUyJf21ghBaVyyZHyOGGhQ': 810,
#  'SqVUNVeYJblyoUz4e-Fiqw': 811,
#  'KGQZvfuthc12iq7p_VzX-w': 812,
#  'uT-yzDkY79szXYNWk7zDzQ': 813,
#  'PIG12rx9hiH4xf9_KBMj4Q': 814,
#  'erJ1HQwavgZx4996SMIxrA': 815,
#  'd_uSfozaAZR4OpDNa8IiZQ': 816,
#  'YVQFzWm0H72mLUh-8gzd5w': 817,
#  'Um-3UHQVVCtrX1m3chK5Bg': 818,
#  'Dqb34bnL4dzwZvySx--qqQ': 819,
#  'QqkTSDnhyCXJqe5y8PdT2A': 820,
#  'YE54kKTuqJJPNYWIKIpOEQ': 821,
#  'iJc4HHs0uYnDFHqcv62CTw': 822,
#  'GWs9J6lIUqrySTxl6uXO0A': 823,
#  '6owWBv_F8Tqti4zmnn2ymA': 824,
#  'TYj0omarAZbxpVggjkreGw': 825,
#  '4krT9JxgkdxLKo7slwOKkA': 826,
#  'iBuWNB9koLWgT0bMPg3eBg': 827,
#  'xcW5lXyjxODJQATvB8xN5A': 828,
#  '6MsHD7EbrjT6COvOeoBeUQ': 829,
#  'dVYmwFWuFwuV3ay2VK5UbA': 830,
#  'EPa3uxyyGfRMpPX47lKwvQ': 831,
#  'l7sZTLRUBK0k3xjRTj1CSA': 832,
#  'kcLuh-ck_Zj07TsodaaNUA': 833,
#  'AH3OZj4glpss6xXpOEHF7Q': 834,
#  'nbVhicAu_-rOrXKh7xV2dA': 835,
#  '4d681x3sCw1Q9ySTyTYXlw': 836,
#  '91OffSkHKrOu9x76iD7Teg': 837,
#  'QFtcFkrpsPVhx91b8veWtw': 838,
#  'NIJWrUAz7-9IEqwZnGBT9g': 839,
#  'IamJ-OX89_P-i-xkknwpPA': 840,
#  'C__1BHWTGBNA5s2ZPH289g': 841,
#  'B49e2hnBhzp7bwBmCPgdxg': 842,
#  'ikaBIGV31VZd1ipFBALORw': 843,
#  'W7ZFD8xThjOX7_O0FDH5kA': 844,
#  'o0emAbW2Z9MnyGxBUzH2ZA': 845,
#  'JFeQMdvX9H6CPtrDxPF0Yw': 846,
#  'u6OIc9ndbqrd6fO_jU2xcw': 847,
#  '6Af3nOBt9pPJd5E-ymnspg': 848,
#  'DCcweTztEpGjZrtHhCWMcQ': 849,
#  'QzebJb11d4AIIVi9kCekqw': 850,
#  'uT88e0NuTpxcqcv3cAyUKA': 851,
#  'fkMiipV4j_DG5nSoBnZvbg': 852,
#  'd8Nz9m-8pYosZKPjd9yNBA': 853,
#  'bgJLZAEaB04x9UQIm3sATQ': 854,
#  'dOxch7C1XaE4aRivX9kJuw': 855,
#  'Dl05etq6qzMf5NOskjb7Ag': 856,
#  'augJQotyLB503iq1gVJ_tg': 857,
#  'U-lHUPZbG8R7Bqxzq8X_lQ': 858,
#  'eTqkngyxFIIoLKm1hq50bg': 859,
#  'YvzoOqfBProz9SveFwJYOw': 860,
#  '3eUPfBdVr1BexmC0bGgCvQ': 861,
#  'SBsQvmEEYJsD6xeRzHxf8Q': 862,
#  'Rw4MCeeV8-CV4yy54aLqiA': 863,
#  'O38E6KW3oiUD9VxHNziakg': 864,
#  'lyfYBqtDGJJ1c98pfLUcLQ': 865,
#  'ufn1IPTJP7mRlmQP3a5dIQ': 866,
#  'lL-wNa0TKK6LXrlcVmjYrQ': 867,
#  'vKUlUXLVylwdttu7h1_Y5Q': 868,
#  'KFZISl5mOUJ6bu3qCUrO-g': 869,
#  '3nDUQBjKyVor5wV0reJChg': 870,
#  '4TcvKrUfYkqoZ6ejnqVY5w': 871,
#  'e1WA0YE3JpTg2Zb_lrHKQA': 872,
#  '7svBs9qqPJHPRXZ56Q3ZuQ': 873,
#  '2VABkVdFhHGMo7wAqfofGA': 874,
#  'oEvsA_IvL0yRyI7d4lT-IA': 875,
#  'hg9nHKYhRUSKWwgnXgn6Jg': 876,
#  'QkhRTrURcY3DW0BLLFPsIw': 877,
#  '0tvCcnfJnSs55iB6mqPk3w': 878,
#  'xD0zXwapBausN9rwNLAXcg': 879,
#  'OaiL5zyYntlvvxTkxzWgvg': 880,
#  'vSnYdIYsF6SJ7mHS9ESSjQ': 881,
#  'FIk4lQQu1eTe2EpzQ4xhBA': 882,
#  'QgRx5RzxLofNAwW_Cw15Yw': 883,
#  'CkqmyV3UWUd70oM3F-PahQ': 884,
#  'oS2O8YQ31HTSTQgPQKc7Cg': 885,
#  'HgCv2lm-GuACRanD7bSqyA': 886,
#  'lxf_9ap6K75XdSn97V8_Mw': 887,
#  'gvuvcjAVl1ElyXTgU80VRg': 888,
#  'MxFNcMUjU5FXG2uqFYiP_g': 889,
#  '9BuTUHt6Zlm-UCjaGD6aJQ': 890,
#  'dF6j86LQWN3RS0r-Oz5Q2A': 891,
#  'n0r_0HkCFaC175vXtIVcaQ': 892,
#  'hilL60vuuh06sMxs6Ckkog': 893,
#  '2_J91lZzqXOYyYeNcVd2YQ': 894,
#  'SCSV8lHxXkS8fdeJTqnomw': 895,
#  'ZcU3nVejaJJ7UhYRtZMNNQ': 896,
#  'JgOcyMF1lTwSVCarSZrrrA': 897,
#  'wzyGNvArcpUjZauRWFrKHA': 898,
#  'GSMFNKyjgfuG5Cxw3B5HLA': 899,
#  'Ry1O_KXZHGRI8g5zBR3IcQ': 900,
#  'gwIqbXEXijQNgdESVc07hg': 901,
#  'IdD1Z_PMqF0zUn3uZWSeAg': 902,
#  'fP_BHT5kAytx1k0H2Erg2A': 903,
#  'e6OZfbZXq4OuPRQlOqO8Ww': 904,
#  'Nhk0jTP2gkU12G4LHJVR3A': 905,
#  'DkLSyxogCcJXY5DbTZ-f2A': 906,
#  'ltUb21ZilinnvIjGbO9FAQ': 907,
#  'sf8w4vCA_ppXUAje04FjOQ': 908,
#  'htiVdsiY_rBmJc65aZ3YAA': 909,
#  'HO-OEQgDzGq3fOK5sQP5Lg': 910,
#  'MPozTU7MRVKYISO5prvzdg': 911,
#  '4RlbldVNFjekCgE50m2CGw': 912,
#  'dqKGX-Zz61Cz62S86mHNmg': 913,
#  'rYAv-1PLU05UGKXWOMee3w': 914,
#  '3Pskc5TXD6WusQZJ3i21Xw': 915,
#  'R4l3ONHzGBakKKNo4TN9iQ': 916,
#  'Zmp1Q6Ul9VH3zL02Z5ls_A': 917,
#  '1FB1Vc4zne5AJAliqdMeWA': 918,
#  'VKP1tppEwu9m4JUmubRCFQ': 919,
#  '4IxVo5Cp3TyyyvH8wOT9yA': 920,
#  '9skLwb3MaL7AJbDB6kHFiQ': 921,
#  'YlQDJExT8gHHcXMiv9geQw': 922,
#  'XNbrAATnVNAg1eTjMjn-pA': 923,
#  '3gRfkaVcEWri-Ju7OQX7uQ': 924,
#  'vpSruwUEfZw_TyaTDHEFDA': 925,
#  'sYBgfT4Qpbg8qe1-nckazQ': 926,
#  '3L7nHnaeSHSdZXzV_vdvAQ': 927,
#  'Reuq65EOFI938Yg8xgff9g': 928,
#  'Z6sMdVaYrFoAOL-Kbc7b3Q': 929,
#  '8EipJXehR14DD9x9N7RSSw': 930,
#  'MeJI77jgRpYkAdOH5kbNLg': 931,
#  'cGn3B71bNKlVigJLjHVNzg': 932,
#  '5vJE4ploStTJHi3PH0YqIA': 933,
#  'PV1Uwnh4TEDZ55Jyud5yRw': 934,
#  '-RCD8F7qbsLfzT3k1HtMxg': 935,
#  'f61aOYfvNhlhmvYfDlzqeQ': 936,
#  'yCaDISH0R8e5U376zDWTpQ': 937,
#  'MylxjEKiTeaWb-GAaPA-zA': 938,
#  'htzxDWzRt4Xd7UGy4t0yAw': 939,
#  'tcFmCEOQj8BqZ4VZheKCrw': 940,
#  'P_GF0rCpPysW5Mskj1L16Q': 941,
#  'UDFIZXP0kOb2xKoYToTS6w': 942,
#  '_5VyC9QOdtManMMLUeSusQ': 943,
#  'WzbiAVIgM4RCuEqNoS1Wcw': 944,
#  'x-Gbs8sVid3yhJIoHD6Gfw': 945,
#  '0IPXId64-RTzDWbTQ7Z_KA': 946,
#  '4SYyFfewOROxJaBLsaxCyQ': 947,
#  'ADNLYx9DMGoGPhZvnviTag': 948,
#  'SAdffUxscHOEygtbQqREIA': 949,
#  'mxwMqra7TEZ6K4ML3DgPmA': 950,
#  'mTuRMYoJwIWXRs6KGUPzIg': 951,
#  'XPAJ2KHkCwBA0vafF-2Zcg': 952,
#  'MFnXQb1R1IGLL_-W4oflJw': 953,
#  'uj4iopBWA0RjpqoJ5xz_vQ': 954,
#  'TaJ3hRYUW9Z82HF0qc4hFQ': 955,
#  'BFcBwoxpkKGUIeUzOU0rRA': 956,
#  '8n06jqTi1y2jP2me20R1ag': 957,
#  '8D8mjeNaJ3DGhl0WX8copA': 958,
#  'UjGjSRA9EIfOVdlOcdXHjw': 959,
#  'SVndZxvQAnZ59AT9xLckRg': 960,
#  'xXyZPAbfQzYTCig7jnZO0A': 961,
#  'chbCROaKWm2pj5uUT-ruGw': 962,
#  'YQ7jD5Wl-Y6mtdUvfCfOIQ': 963,
#  'MTB3KvE5NCiQSO5QOvAilw': 964,
#  '7YkAI5_NfbcwhQeKMSZRwg': 965,
#  '1SFfDyD0TA1dnXmbPTRMVQ': 966,
#  'i7mBC7m7k2FLrdVUx0UqUg': 967,
#  'eBoyunRiJb-QzwQbv1-1bw': 968,
#  'B-60XQ_fR72PevFzHM-ieQ': 969,
#  'x9rkVoNB92HR_bFOe6MFTQ': 970,
#  'ZyJD2v2-BcSDWVW4IkQMrA': 971,
#  '1HhGzu9BW5kUfpi1_9pCbg': 972,
#  'Jm67TDhh8t1VHPACeORuOg': 973,
#  'ddDPOUDTV3RdwkRuYu1GLQ': 974,
#  'anTmWtK-REFMAaLPzD5-ng': 975,
#  'j1jXmA4__4UWIplZk6MJMQ': 976,
#  'y2kxWCanqSRDBo50wiQE2Q': 977,
#  'iHGsi2zgjGEm2zEQg8w0og': 978,
#  '16wUxTF_jIH8d82IxFUD0g': 979,
#  'O3pSxv1SyHpY4qi4Q16KzA': 980,
#  'AvC5XQAElcGAAn_Wr5auEg': 981,
#  'Mf8dFqdz3F39w8it_Ob2Pw': 982,
#  '-9JqNce6qGY2fTepA8XpUg': 983,
#  'dnv5UpldAE6UITDcMleLVA': 984,
#  'EtBYV4tWrKH6jR0RCwV_JA': 985,
#  'KhrVbHqtDSvUnigNc0JVUg': 986,
#  'OXuL4nKwbBUw6lIH5EUngA': 987,
#  'qIIWAMJ_LwlJi0fntUpsjg': 988,
#  'Kh0cFp8G0CPAtyphCKxkiw': 989,
#  'CjbfWpCRLbA-L_eS_ztd6Q': 990,
#  'b3tK3CkLOfrWpSuvn9Yo1g': 991,
#  'J76FnutwAI2PkkB4A-LNwg': 992,
#  'I2uiqGOwg6uBNX3SXRGiFg': 993,
#  'ic-tyi1jElL_umxZVh8KNA': 994,
#  'dKKTpZ8TeX8qv4gT_otDHQ': 995,
#  '_ABftW6CZdx4iMdHaCkiZA': 996,
#  '5KzHxAaHgG0UCUQiaXH5oQ': 997,
#  'TK8Nf2vUC_aJgtDlBNAoBA': 998,
#  'oVf_KD7B1aLGqINy5Dlw4w': 999,
#  ...}

# %% [markdown]
# **Hash Functions**

# %%
def generate_hash_functions(num_funcs, max_val, prime=2147483647):
    funcs = []
    for _ in range(num_funcs):
        a = random.randint(1, prime - 1)
        b = random.randint(0, prime - 1)
        funcs.append(lambda x, a=a, b=b: ((a * x + b) % prime) % max_val)
    return funcs

# %%
num_hashes = 100
max_val = len(user_id_index)
hash_funcs = generate_hash_functions(num_hashes, max_val)

# %% [markdown]
# **Signature Matrix**

# %%
signature_matrix = {}
for business, users in business_users_map.items():
    sig = []
    for func in hash_funcs:
        min_hash = min(func(user_id_index[user]) for user in users)
        sig.append(min_hash)
    signature_matrix[business] = sig

# %% [markdown]
# **LSH**

# %%
bands = 20
rows_per_band = num_hashes // bands
buckets = defaultdict(list)

# %%
for band in range(bands):
    for business, sig in signature_matrix.items():
        band_signature = tuple(sig[band * rows_per_band: (band + 1) * rows_per_band])
        band_hash = hashlib.md5(str(band_signature).encode()).hexdigest()
        buckets[(band, band_hash)].append(business)

# %%
candidate_pairs = set()
for bucket in buckets.values():
    if len(bucket) > 1:
        for pair in combinations(sorted(bucket), 2):
            candidate_pairs.add(pair)

# %% [markdown]
# **Jaccard Similarity**

# %%
def jaccard(set1, set2):
    return len(set1 & set2) / len(set1 | set2)

# %%
similar_pairs = []
for b1, b2 in candidate_pairs:
    sim = jaccard(business_users_map[b1], business_users_map[b2])
    if sim >= 0.5:
        similar_pairs.append((b1, b2, sim))

# %% [markdown]
# **Sorting the results**

# %%
similar_pairs_sorted = sorted(similar_pairs, key=lambda x: (x[0], x[1]))

# %% [markdown]
# **Save to CSV**

# %%
with open("similar_businesses.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(["business_id_1", "business_id_2", "similarity"])
    writer.writerows(similar_pairs_sorted)

# %% [markdown]
# ## MapReduce

# %%
from pyspark import SparkConf, SparkContext
import os

# %%
os.environ["JAVA_HOME"] = "C:\\Program Files\\Java\\jre1.8.0_451"
os.environ["SPARK_HOME"] = "C:\\Spark\\spark-3.5.5-bin-hadoop3" 
os.environ["HADOOP_HOME"] = "C:\\hadoop"
os.environ["PYSPARK_PYTHON"] = "D:\\Master_Semester2\\BigData\\Assignments\\Assignment1\\.venv\\Scripts\\python.exe"
os.environ["PYSPARK_DRIVER_PYTHON"] = "D:\\Master_Semester2\\BigData\\Assignments\\Assignment1\\.venv\\Scripts\\python.exe"
os.environ["PATH"] += ";" + os.path.join(os.environ["SPARK_HOME"], "bin")

# %%
def loadMovieNames() :
    movieNames = {}
    with open("Data/movies.txt", encoding = "ISO-8859-1") as f:
        for line in f:
            fields = line.split('|')
            movieNames[int(fields[0])] = fields[1]
    return movieNames

# %%
conf = SparkConf().setAppName("WorstMovies")
sc = SparkContext(conf = conf)
movieNames = loadMovieNames()

# %%
lines = sc.textFile("Data/users.txt")

# %%
movieRatings = lines.map(lambda x: (int(x.split()[1]), (float(x.split()[2]), 1)))

# %%
ratingTotalsAndCount = movieRatings.reduceByKey(lambda a, b: (a[0]+b[0], a[1]+b[1]))

# %%
averageRatings = ratingTotalsAndCount.mapValues(lambda x: x[0] / x[1])

# %%
bestMovie = averageRatings.max(key=lambda x: x[1])
worstMovie = averageRatings.min(key=lambda x: x[1])

# %%
print("Best Movie:")
print(f"{movieNames[bestMovie[0]]} with average rating of {bestMovie[1]:.2f}")
# Out:
# Best Movie:
# Santa with Muscles (1996) with average rating of 5.00

# %%
print("\nWorst Movie:")
print(f"{movieNames[worstMovie[0]]} with average rating of {worstMovie[1]:.2f}")
# Out:
# Worst Movie:
# Amityville: Dollhouse (1996) with average rating of 1.00
